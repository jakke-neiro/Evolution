# %% [markdown]
# Mycologica, Sienitiede, Mykologi
#
# Fungi: is any member of the group of eukaryotic organisms that includes unicellular microorganisms such as yeasts and molds, as well as multicellular fungi that produce familiar fruiting forms known as mushrooms.
# Sieni: sienet ovat aitotumaisia, toisenvaraisia ja lehtivihreättömiä eliöitä, jotka hajottavat kuollutta eloperäistä materiaalia ja elävät loisina.
# Svamp: bildar vid sidan om djur, växter, protister och bakterier ett eget rike bland organismerna. De skiljer sig från växterna genom att de saknar klorofyll och är heterotrofa, och de skiljer sig från djuren genom att de absorberar sin föda snarare än äter den samt att de har cellväggar (av kitin och glukaner).
# 1.  Structure, Rakenne, Struktur
# Hyphae: is a long, branching filamentous structure of a fungus, oomycete, or actinobacterium. In most fungi, hyphae are the main mode of vegetative growth, and are collectively called a mycelium. Yeasts are unicellular fungi that do not grow as hyphae.
# Hyyfit eli sienirihmat, hyfer: monisouiset sienet ovat olemukseltaan rihmamaisia
#
# Mycelium, sienirihmasto, mycelium: yhtenäinen, yleensä haarainen, sienirihmoista muodostuva rihmasto, joka on monisouisten sienten kehityskierron vallitseva vaihe.
#
# Septate hyphae: väliseinällisiä hyyfejä
# Coenocytic hyphae: monitumaisia putkia
# Mycorrhizae, Sienijuuri, mykoritsa, mykorhiza: kokonaisuus, jonka muodostavat kasvin juuri ja sen kanssa symbioosissa elävä sienirihmasto
# Ectomycorrhiza, Ektomykoritsa, Ektomykorhiza: sieniosakas näkyy juurissa päällepäin
# Endomykoritsa: sieniosakas on juuren sisällä, solujen välissä ja soluissa.
# Haustoria: specialized hyphae used to extract or exchange nutrients withn plants
#
# Cell wall: chitin, glycan and glycoproteins
#
#
# 2. Reproduction
# Haploic life cycle
#
#
#
#
#
#
#
#
#
#
#
#
# Plasmogamy: Plasmogamy is a stage in the sexual reproduction of fungi, in which the cytoplasm of two parent cells (usually from the mycelia) fuses together without the fusion of nuclei, effectively bringing two haploid nuclei close together in the same cell.
# Karyogamy: Karyogamy is the final step in the process of fusing together two haploid eukaryotic cells, and refers specifically to the fusion of the two nuclei.
# Heterokaryotic, dikaryotic
#
# The heterokaryotic condition also offers some of the advantages of diploidy in that one haploid genome may compensate for harmful mutations in the other.
#
#
# 1. Chytridomycota, Chytrids,Piiskasiimasienet, Gisselsvampar
# Flagellated zoospores
# 2. Zygomycetes, Yhtymäsienet, Kopplingssvampar
# Zygosporangium, a multinucleate structure, first heterokaryotic with many haploid nuclei from two parents, then with many diploid nuclei after karyogamy
# Yhtymäitiö: kahden rihman päät sulautuvat yhteen ja muodostavat paksuseinäisen yhtymäitiön
# Haploic life cycle
#
#
# 3. Glomeromycetes, Keräsienet,
# Endomycorrhiza
#
# 4. Ascomycota, Ascomycetes, Kotelosienet, Sporsäckssvampar
# Ascus, itiökotelo: spore-forming organ
# Ascocarp: system of asci
# Sexual spores borne internally in sacs called asci
# Vast numbers of asexual spores, conidia. Conidia are not formed inside sporangia, as are the asexual spores of most zygomycetes.
# Kotelosienten sienirihmoissa on väliseinät ja suvulliseen lissäntymiseen liittyy itiökoteloiden muodostuminen
# Neurospora crassa
#
# 5. Basidiomycetes, Kantasienet, Basidiesvampar
# Elaborate fruiting body (basidiocarp) containing many basidia that produce sexual spores (basidiospores)
# Kantasienten sienirihmoissa on aukolliset välisienät ja suvulliseen lisääntymiseen liittyy itiökantojen eli basidioiden muodostus
#
# Fruiting body, Itiöemä. Fruktkropp: lukuisilla sienillä tavattava pseudoparenkyymistä muodostuva rakenne, jossa lisääntymistä välittävät itiöt syntyvät.
