# %% [markdown]
# \section{Introduction}
# 1. Introduction, Johdanto, Inledning
# Evolution: Descent with modification; the idea that living species are descendants of ancestral species that were different from the present-day ones; also defined more narrowly as the change in the genetic composition of a population from generation to generation. Evolution is change in heritable traits of biological populations over successive generations
# Evoluutio: luonnonilmiö, jonka mukaan organismien muoto ja elämäntapa ovat muuttuneet ja jatkuvasti muuttuvat siten, että jälkeläiset eroavat kantamuodoistaan. Evoluutio on muutosta populaation geenifrekvenseissä
# Evolution: naturfenomen enligt vilken organsimernas form och levnadssätt har förändrats och fortsätter att förändras, så att avkomlingarna skiljer sig från sina förfäder. Evolution är förändrign i populationens allelförhållanden.
# Evolutionen beskriver hur levande organismer förändras över tiden genom ändringar i den genetiska arvsmassan.
# I	II	III	IV	V
# Evolution	Common ancestor
# Yhteinen kantamuoto
# Gemensamt stamform	Gradualism	Species diversification	Natural selection
# Luonnonvalinta
# Naturligt urvak
#
# Variation+Inheritance+selection=evolution
# Muuntelu+Perinnöllisyys+valinta=evoluutio
# Variation+Ärftlighet+selektion=evolution
# Microevolution is the change in allele frequencies that occurs over time within a population.[1] This change is due to four different processes: mutation, selection (natural and artificial), gene flow, and genetic drift. This change happens over a relatively short (in evolutionary terms) amount of time compared to the changes termed 'macroevolution' which is where greater differences in the population occur.
# Mikroevoluutio: lajin sisäinen evoluutio, joka tapahtuu muutoksina populaation geenien esiintymistiheyksissä
# Mikroevolution: Mikroevolution är uppkomsten av småskaliga förändringar i en populations genfrekvens under några generationer. Detta kallas även förändringar under artnivå. Dessa förändringar kan bero på flera saker, exempelvis mutation, genflöde, genetisk drift eller det naturliga urvalet.
#
# Macroevolution is evolution on a scale of separated gene pools.[1] Macroevolutionary studies focus on change that occurs at or above the level of species, in contrast with microevolution,[2] which refers to smaller evolutionary changes (typically described as changes in allele frequencies) within a species or population.[3] Macroevolution and microevolution describe fundamentally identical processes on different time scales.[1][4]
# Makroevoluutio: lajinkehitys; evoluutio, joka johtaa uusien lajien syntyyn. Makroevoluutio voidaan johtaa mikroevoluutiosta isolaation käsitteen mukaanoton avulla.
# Makroevolution innebär större förändringar av genpoolen, till exempel bildandet av nya arter, släkten eller familjer. Biologer definierar makroevolution som förändringar på eller över artnivå [1][2][3][4] Termerna makroevolution och mikroevolution myntades år 1927 av den ryske entomologen Jurij Filiptjenko.
#
# Megaevolution describes the most dramatic events in evolution. It is no longer suggested that the evolutionary processes involved are necessarily special, although in some cases they might be. Whereas macroevolution can apply to relatively modest changes that produced diversification of species and genera and are readily compared to microevolution, "megaevolution" is used for great changes. Megaevolution has been extensively debated because it has been seen as a possible objection to Charles Darwin's theory of gradual evolution by natural selection
# Megaevoluutio: korkeampien systemaattisten taksonien, kuten sukujen, heimojen jne. evoluutio
# Megaevolution: evolutionen av högre systematiska taxoner
#
# 2. History
# The modern evolutionary synthesis is a 20th-century synthesis of ideas from several fields of biology that provides a widely accepted account of evolution. It is also referred to as the new synthesis, the modern synthesis, the evolutionary synthesis,millennium synthesis or the neo-Darwinian synthesis.
# Neodarwinismi: evoluutioteorian 1920-40-luvuilla syntynyt muoto, jossa darwinismin perusperiaate eli luonnonvalinnan teoria on yhdistetty perinnöllisyystieteen teorioihin.
#
# 1. Introduction
# Evolution is not goal orientated
# Why not perfect organisms?
# -existing variation for selection
# -historical restraints
# -compromises
# -stochaism
#
#
#
#
#
# All evolutionary phenomena can be explained in a way consistent with known genetic mechanisms and the observational evidence of naturalists.
# Evolution is gradual: small genetic changes regulated by natural selection accumulate over long periods. Discontinuities amongst species (or other taxa) are explained as originating gradually through geographical separation and extinction. This theory contrasts with the saltation theory of William Bateson (1894).[7]
# Natural selection is by far the main mechanism of change; even slight advantages are important when continued. The object of selection is the phenotype in its surrounding environment.
# The role of genetic drift is equivocal. Though strongly supported initially by Dobzhansky, it was downgraded later as results from ecological genetics were obtained.
# Thinking in terms of populations, rather than individuals, is primary: the genetic diversity existing in natural populations is a key factor in evolution. The strength of natural selection in the wild is greater than previously expected; the effect of ecological factors such as niche occupation and the significance of barriers to gene flow are all important.
# In palaeontology, the ability to explain historical observations by extrapolation from microevolution to macroevolution is proposed. Historical contingency means explanations at different levels may exist. Gradualism does not mean constant rate of change.
#
#
# Evidence for evolution, Evoluution todisteet, Bevis för evolutionen
#
# 1. Fossil, Fossiili, Fossil
# Fossils (from Classical Latin fossilis; literally, "obtained by digging")[1] are the preserved remains or traces of animals, plants, and other organisms from the remote past. The totality of fossils, both discovered and undiscovered, and their placement in fossiliferous (fossil-containing) rock formations and sedimentary layers (strata) is known as the fossil record.
# Fossiili: maa- tai kallioperässä säilynyt entisaikojen (vähintään 10 000 vuotta vanha) eliön jäänne tai jälki, joka voi olla eliö itse, sen osa, valos (cast) tai kivettymä (trace fossil), kun elävän kudoksen molekyylit ovat korvautuneet epäorgaanisilla aineilla.
# Fossil: Fossil (av latin fossus, "uppgrävd") är djur- eller växtdelar som bevarats i typer i sediment eller sedimentära bergarter. En fossilisering kräver att växtdelarna och/eller det omgivande sedimentet mineraliseras. Fossilbildning eller förstening innebär alltså ett utbyte av substans, det vill säga en fysikalisk-kemisk omvandling av material.
# =lämningar av forntida organismer, > 10 000 år, förstening, avtryck, avgjutning, bärnsten
#
# 1. Fossil series, Fossiilisarjat, Fossilserier
# Index fossils, Johtofossiili, Ledfossil
# Index fossils (also known as guide fossils, indicator fossils or zone fossils) are fossils used to define and identify geologic periods (or faunal stages). They work on the premise that, although different sediments may look different depending on the conditions under which they were laid down, they may include the remains of the same species of fossil.
#
# 2. Translational fossil, Välimuotofossiili, intermediärfossil
# A transitional fossil is any fossilized remains of a life form that exhibits traits common to both an ancestral group and its derived descendant group. This is especially important where the descendant group is sharply differentiated by gross anatomy and mode of living from the ancestral group.
# Missing link, Puuttuva rengs, Felande lank
# Archaeopteryx, Tiktaalik, Australopithecus afarensis
#
# 3. Subfossil, Subfossiili, Subfossil
# A subfossil (as opposed to a fossil) is a bone or other part of an organism that has not fully fossilized. This may be because not enough time has elapsed since the animal died, or because the conditions in which the remains were deposited were not optimal for fossilization.
#
# 4. Living fossil, Elävä fossiili, Levande fossil
# A living fossil is a living species (or clade) of organism that appears to be similar to a species otherwise known only from fossils. Normally the similarity is only a superficial physical resemblance between two different species, one extinct, the other extant.
# Elävät fossiilit ovat nykyisin eläviä jäänteitä eliöryhmistä, jotka varhaisempina geologisina aikoina ovat olleet runsaslukuisempia ja laajemmalle levinneitä.
#
# 3. Homologa vs. analoga organ
# Homology: In the context of biology, homology is the existence of shared ancestry between a pair of structures, or genes, in different species.[1] A common example of homologous structures in evolutionary biology are the wings of bats and the arms of primates.
# Analogy: Structural or behavioural similarity in terms of functions between unrelated species or organisms but do not share a common ancestral or developmental origin
#
# Homologia: homologiset rakenteet tai ominaisuudet ova fylogeneettiseltä alkuperältään samansyntyisiä, mutta niiden toiminta tai tehtävä saattaa olla erilainen
# Analogia: analogiset rakenteet; elimiä, joilla on eri evolutiivinen aluperä mutta sama tehtävä
# Homologi: homologi är inom biologi ett evolutionärt begrepp för att beskriva att specifika morfologa eller genetiska egenskaper hos olika organismer har samma ursprung. All systematik och alla fylogenier (hypoteser om släktskap) bygger på att man identifierar homologier hos olika organismer.
# Analogia: Analogi eller homoplasi är inom evolutionsbiologin en beteckning på en morfologisk och/eller genetisk likhet mellan två taxa som inte uppkommit genom nedärvda karaktärer från en gemensam förfader, utan istället genom parallell evolution, konvergent evolution (framkallat av ett likartat levnadssätt) eller reversion (återgång till ett ursprungligare karaktärsstadium).
# 4. Embryology, Embryologia, Embryologi
# Ontogeny recapitulates phylogeny
# Ontogenia rekapituloi fylogenian
# Ontogeni rekapitulerar fylogeni
# 5. Vestigal structures, surkastuma, rudiment
# Vestigiality refers to genetically determined structures or attributes that have apparently lost most or all of their ancestral function in a given species, but have been retained during the process of evolution.[1] Assessment of the vestigiality must generally rely on comparison with homologous features in related species
# Surkastuma: Evolutiivessa kehityksessä tehtävänsä menettänyt elin tai sen osa;esim. ihmisen häntänikamat, umpilisäke.
# Rudiment: Rudiment, ofta kallade rudimentära organ även om långt ifrån alla rudiment är organ, avser inom biologin rester av tidigare utvecklingsformer vars ursprungliga funktion helt eller i huvudsak gått förlorad genom evolution utan att för den skull helt försvunnit (en del rudiment försvinner dock innan djuret fötts eller nått vuxen ålder)
#
# H. sapiens: umpilisäke, korvalihakset, häntänikamat, kulmahampaat, karvapeite
# H. sapiens: blindtarmens bihang, örönmuskeln, svanskota, hörntänder, kroppshår
# 6. Biokemi
# Kromosomer, DNA, proteiner
#
# 7. Behaviour, Käyttäytyminen, Beteende
# 8. Biogeografi
# 9. Pågående evolution
# 1.Industrial melanism, Teollisuusmelanismi, Industrimelanism
# 2. Resitent bacteria, Tesistentit bakteerit, Resistenta bakterier
# 3. Breeding, Jalostus, Förädling
# 10. Taxonomy and Linnean hierarchy, Taksonomia ja linneläinen hierarkia, Taxonomi och Linnés hierarki
#
# \section{Evolutionary mechanisms}
# Genetic variation makes evolution possible
#
# Variation: Genetic variation is a fact that a biological system – individual and population – is different over space. It is the base of the genetic variability of different biological systems in space.
# Muuntelu: periytyvien tai peritymättömien erojen esiintyminen populaation yksilöiden välillä. Fenotyyppinen muuntelu on ympäristön aiheuttaman ja geneettisen munntelun summa
# Variation: det faktum att det förekommer genetiska och icke-ärftliga skillnader mellan individerna i en population
# Epigenetic: epigenetics is the study, in the field of genetics, of cellular and physiological phenotypic trait variations that are caused by external or environmental factors that switch genes on and off and affect how cells read genes instead of being caused by changes in the DNA sequence
# Epigenetiikka: geeniaktiivisuuden säätely ilman geneettisten rakenteiden muutoksia
# Epigenetik: regleringen av genaktiviteten utan strukturella förändringar i det genetiska materialet
#
# Vanhempien kokemat olot vaikuttavat jälkeläisten geenien säätelyyn.
#
# Recombination or genetic recombination: Genetic recombination is the production of offspring with combinations of traits that differ from those found in either parent. In eukaryotes, genetic recombination during meiosis can lead to a novel set of genetic information that can be passed on from the parents to the offspring.
# Rekombinaatio eli geneettinen rekombinaatio: prosessi, jonka vaikutuksesta kaksi eliötä yhdentyy niin, että niiden jälkeläisissä esiintyy geeniyhdistelmiä, joita ei vanhemmilla tavata.
# Rekombination eller genetisk rekombination: den process som leder till att avkomlingarna har annorlunda genkombinationer jämfört med sina föräldrar.
# Epäjatkuva muuntelu: dimorfismi, polymorfismi
# Jatkuva muuntelu eli kvantitattiviset ominaisuudet
# Muuntelun mittaaminen
# Yksilötasolla: Populaation yksilöiden heterotsygotian keskiarvo
# Geenitasolla: heterotsygoottisten lokusten osuus
# Molekyylitasolla: sekvenssin muuntelevien nukleotidien osuus
#
# In ecology and genetics, a reaction norm, also called a norm of reaction, describes the pattern of phenotypic expression of a single genotype across a range of environments.
#
# Genetisk variation sparas
# -diploidy
# -balanserande selection
# heterozygotens fördel, frekvensberoende
#
# Population genetics, Populaatiogenetiikka, Populationsgenetik
#
# The gene pool is the set of all genes, or genetic information, in any population, usually of a particular species.
# Geenipooli: tietyn mendelistisen population geenistön koostumus tiettynä ajankohtana. Geenipoolin, joka pysyy muuttumattomana sukupolvien kuluessa, sanotaan olevan tasapainossa.
# Genpool: En genpool är frekvensen för alla alleler (genvarianter) som finns i en viss population. Genpooler studeras i populationsgenetik och evolutionsforskning. Genpoolen förändras framförallt av att alleler med ökad fitness ökar sin frekvens genom att dess bärare (individer) har större framgång i sin förökning genom naturligt urval och för genvarianterna vidare till nästa generation.
#
# Hardy-Weinberg law: The Hardy–Weinberg principle, also known as the Hardy–Weinberg equilibrium, model, theorem, or law, states that allele and genotype frequencies in a population will remain constant from generation to generation in the absence of other evolutionary influences. These influences include mate choice, mutation, selection, genetic drift, gene flow and meiotic drive.
# Hardy-Weinbergin laki: populaatiogenetiikan peruslaki, jonka mukaan geenifrekvenssit populaatiossa pysyvät muuttumattomina, ellei mikään muu tekijä kuin sattumanvarainen pariutuminen vaikuta.
# Hardy-Weinbergs lag: en populations genfrekvenser kommer att förbli oförändrade om populationen inte påverkas av evolutionära influenser.
#
# 1. no mutations
# 2. random mating
# 3. No selection
# 4. Big population
# 5. No gene flow
#
#
# Talförhållandet mellan allelerna konstant vid mendelsk rekombination = Hardy-Weinberg jämvikt
# -> förändrade faktorer -> mikroevolution
#
#
#
# 3. Evolution factors, Evoluutiotekijät, Evolutionsfaktorer
# =regulates variation, changes allele frequencies -> microevolution
# De fem evolutionskrafterna: urval, drift, genflöde, mutation, rekombination
# 1. Natural selection, Luonnonvalinta, Naturligt urval
# Natural selection: Natural selection is the differential survival and reproduction of individuals due to differences in phenotype, it is a key mechanism of evolution.
# Luonnonvalinta: luonnonvalinnan idea on se, että kelpoisimmat muunnokset jäävät olemassaolon taistelussa henkiin ja saavat jälkeläisiä.
# Naturligt urval: Det naturliga urvalet är en nödvändig delprocess i evolutionen. Charles Darwin var den som tillsammans med Alfred Russell Wallace, lade fram teorin om det naturliga urvalet som förklaring till de observerade skillnaderna mellan olika arter.
#
# Konkurrens -> de mest dugliga överlever -> överför sina egenskaper och gener -> påverkar genernas talförhållanden i populationen i nästa generation, genetiska representation -> mikroevolution
#
# Selection unit=individ
# Morfologi, Fysiologi, Etologi
# 1. Överflöd av individer
# 2. Stabila populationer
# 3. Miljöns bärförmåga överskrids
# -> kamp om tillvaron
# 4. Variation
# -> olika fitnesskillnader
# 5. Ärftlighet
# -> evolution
#
#
#
# 2. Fitness and adaption
# Fitness: Fitness (often denoted w in population genetics models) is a central idea in evolutionary and sexual selection theories. It can be defined either with respect to a genotype or to a phenotype in a given environment. In either case, it describes individual reproductive success and is equal to the average contribution to the gene pool of the next generation that is made by an average individual of the specified genotype or phenotype.
# Kelpoisuus: perinnöllisyystieteessä yksilön tai genotyypin suhteellinen kyky saada lissätymiskykyisiä jälkeläisiä
# Fitness: relativ fortplantningsförmåga
# Fitness,Kelpoisuus, Duglighet
# 1. Survival, Elossasäilyminen, Överlevnad
# 2. Reproduktion, Lisääntyminen, Reproduktion
# 3. Omsorg
#
# In biology, an adaptation, also called an adaptive trait, is a trait with a current functional role in the life of an organism that is maintained and evolved by means of natural selection. Adaptation refers to both the current state of being adapted and to the dynamic evolutionary process that leads to the adaptation. Adaptations enhance the fitness and survival of individuals.
# Sopeutuma: eliön rakenteessa tai toiminnassa mikä tahansa muutos, joka antaa sille paremman mahdollisuuden tulla toimeen ympäristössään. Adaptaation tuloksena eliö sopeutuu rakenteellisesti ja toiminnallisesti ympäristöönsä.
# Adaption: genetiskt betingad förändring som leder till att en organism med tiden blir batter anpassad till sin miljö. Adaption avser någon strukturell eller funktionell förändrng som ökar en organisms möjligheter att överleva och reproducera sig.
# Inclusive fitness
# Morphology, Physiology, Etology
#
# Selektionsformer
# 1.Stabilizing,
# Tasapainottava,
# Stabiliserande
# 	2. Directional
# Suuntaava
# Riktad	3. Disruptive
# Hajottava
# Diverfisierande
#
#
#
#
#
#
#
#
#
#
# 2. Sexual selection, Sukupuolivalinta, Sexuell selection
# Sexual selection: Sexual selection is a mode of natural selection where typically members of one gender choose mates of the other gender to mate with, called intersexual selection, and where females normally do the choosing, and competition between members of the same gender to sexually reproduce with members of the opposite sex, called intrasexual selection.
# Sukupuolivalinta: on valinnan muoto, jossa sukupuoleen liittyvillä ominaisuuksilla on tärkeä merkitys.
# Sexuell selektion: teori som säger att hanar av vissa arter konkurrerar om honorna och att vissa karakteristika då utvecklas i denna konkurrens, antingen prydnader eller beteenden som lockar honorna, eller vapen som utnyttjas i kampen med andra hanar.
#
# =more likely to obtain mates -> sexual dimorphism
# Intersexual vs. intrasexual
# Fischer 1930 runaway process
# Zahov 1975 handicap principle
#
# Ornament, Ornamentti, Ornament
# 3. Genetic drift, Geneettinen ajautuminen tai satunnaisajautuminen, genetisk drift
# Genetic drift: Genetic drift (or allelic drift) is the change in the frequency of a gene variant (allele) in a population due to random sampling of organisms.
# Geneettinen ajautuminen: pienissä populaatioissa oleva tekijä, jonka vaikutuksesta geenifrekvenssit populaatiossa heilahtelevat sattumalta edestakaisin, kunnes niiden arvoksi lopulta tulee ykkönen tai nolla.
# Genetisk drift: Genetisk drift är en av delmekanismerna i evolutionen. Den är en stokastisk effekt och uppkommer på grund av den slumpmässighet som råder i vilka individer i populationerna som lyckas (bäst) med att överleva och reproducera sig.
# 1. Founder effect, perustajanvaikutus, grundareffekten
# Founder effect: In population genetics, the founder effect is the loss of genetic variation that occurs when a new population is established by a very small number of individuals from a larger population. It was first fully outlined by Ernst Mayr in 1942,[1] using existing theoretical work by those such as Sewall Wright.
# Perustajanvaikutus: populaatiogeneettinen ilmiö, jossa uuden, muuttoliikkeen kautta syntyneen population geenitaajuudet eli geenifrekvenssit voivat sattumalta poiketa peruspopulaation geenitaajuuksista:
# Grundareffekten: Grundareffekten är den förlust av genetisk variation som uppkommer när en ny mindre population grundas av ett mindre antal individer från en större population. Grundareffekten är ett extremfall av genetisk drift.[1][2] Begreppet är centralt inom populationsgenetiken och beskrevs fullständigt för första gången av Ernst Mayr år 1952[3], baserat på teoretiskt arbete av bland annat Sewall Wright.
#
# 2. Bottleneck effect, pullonkaulailmiö, flaskhalseffekten
# A population bottleneck (or genetic bottleneck) is a sharp reduction in the size of a population due to environmental events (such as earthquakes, floods, fires, disease, or droughts) or human activities (such as genocide). Such events can reduce the variation in the gene pool of a population; thereafter, a smaller population with a correspondingly smaller genetic diversity, remains to pass on genes to future generations of offspring through sexual reproduction.
# 4. Gene flow (migration), geenivirta (migraatio), genflöde (migration)
# Gene flow: In population genetics, gene flow (also known as gene migration) is the transfer of alleles or genes from one population to another.
# Geenivirta: Geenien siirtyminen populaatiosta toiseen lissäntymisvälikappaleiden, kuten siementen, siitepölyn ja itiöiden, leviämisen tai yksilöiden siirtymisen, migration, kautta. Geenivirta voi johtaa geenifrekvenssien muutoksiin ja on siten evoluutiossa vaikuttava tekijä.
# Genflödet: Genflöde är när gener överförs från en population till en annan population av samma art. Då flera populationer utbyter gener mellan varandra i en kedja kan det uppstå en rascirkel. Genflöde är den enda evolutionsprocessen som gör populationerna genetiskt mer lika varandra. Genflöde gör också att genpoolerna blir större.
#
#
#
# 4. Speciation, Lajiutuminen, Artbildning
# Speciation is the evolutionary process by which new reproductively isolated biological kinds, species, arise. The biologist Orator F. Cook was the first to coin the term 'speciation' for the splitting of lineages or "cladogenesis," as opposed to "anagenesis" or "phyletic evolution" occurring within lineages.
# Lajiutuminen: lajien evolutiivinen muotoutuminen lisääntymisisolaation kehittyessä populaatioiden tai populaatioryhmien välille
# Artbildning är när nya arter uppstår, och orsaken till livets stora mångfald. Forskare tror att det finns cirka 10 miljoner arter på jorden just nu, men endast 1,4 miljoner av dessa har blivit upptäckta, vetenskapligt beskrivna och därmed namngivna. Nya arter bildas alltid från en redan befintlig art.
#
# Populationen isoleras I delpopulationer, olika evolutionsfaktorer -> anagenes I olika riktiningar -> kladogenes -> macroevolution
# Anagenesis, also known as "phyletic transformation", is when the new morphospecies is a result of rapid evolution in the ancestral form without speciation taking place, such that there are no remaining other populations of the ancestor species and the species can be considered extinct. The ancestor species is therefore superseded by the new species it morphs into. Anagenesis is in contrast to the branching speciation known as cladogenesis.
# Anageneesi: progressiivisen evolution muoto, johon liittyy uusien eliten, rakennetyyppien ja rakenneratkaisujen syntymistä. Anageneesi johtaa uuden lajin syntyyn kantalajin haarautumatta kahdeksi tai useammaksi lajiksi. Julian Huxleyn mukaan anagenees on yleistermi kaikenlaiselle evoluutiolle, joka johtaa biologisen sopeutumisen paranemiseen.
# Cladogenesis is an evolutionary splitting event where a parent species splits into two distinct species, forming a clade.[1]This event usually occurs[citation needed] when a few organisms end up in new, often distant areas or when environmental changes cause several extinctions, opening up ecological niches for the survivors.
# Kladogeneesi: fyleettisen evolution muoto, jossa yksi laji haarautuu kahdeksi lajiksi.
#
# Divergent evolution is the accumulation of differences between groups which can lead to the formation of new species, usually a result of diffusion of the same species to different and isolated environments which blocks the gene flow among the distinct populations allowing differentiated fixation of characteristics through genetic drift and natural selection.
#
# Convergent evolution is the independent evolution of similar features in species of different lineages. Convergent evolution creates analogous structures that have similar form or function, but that were not present in the last common ancestor of those groups.[1] The cladistic term for the same phenomenon is homoplasy, from Greek for same form.
#
# Parallel evolution is the development of a similar trait in related, but distinct, species descending from the same ancestor, but from different clades.
#
#
# Sympatric speciation is the process through which new species evolve from a single ancestral species while inhabiting the same geographic region. In evolutionary biology and biogeography, sympatric and sympatry are terms referring to organisms whose ranges overlap or are even identical, so that they occur together at least in some places.
# Sympatrinen lajiutumien syntyy ilman maantieteellistä eristymistä, ts. lisääntymisisolaation syntyminen deemin sisällä
#
# Allopatric speciation (from the ancient Greek allos, "other" + Greek patris, "fatherland") or geographic speciation is speciation that occurs when biological populations of the same species become vicariant, or isolated from each other to an extent that prevents or interferes with genetic interchange.
# Allopatrinen lajiutuminen on seurausta maantieteellisestä eristyneisyydestä, ts. populaatioiden välille kertyy niiden eläessä maantieteellisesti eristyneinä niin paljon geneettisiä eroja erilaisten valintapaineiden vuoksi.
# Allopatric, Allopatrinen, Allopatrisk	Sympatric, Sympatrinen, Sympatrisk
# 1. Dikopatric	1. Hybridisation
# 2. Peripatric	2. Polyploidy
# 3. Rengaslajit, RIngarter	3. Habitat difference
# 	4. Sexual selection
#
# Reproductive barriers or isolation mechan isms
# Lisääntymisesteet eli isolaatiomekanismit
# Förökningsbarriärer alltså isolationsmekanismer
# 1. Geographical, Maantieteellinen, Geografisk	Prezygotic
# Pretsygoottinen
# Prezygotisk
# 2. Habitat, Habitaatti, Habitat
# 3. Temporal, Temporaalinen, Tidsmässig
# 4. Behavioral, Käyttäytyminen, Beteende
# -
# 5. Mechanical, Mekaaninen, Mekanisk
# 6. Gametic, Gameettinen, Gametisk
# -
# 7. Reduced hybrid viability	Postzygotic
# Postzygoottinen
# Postzygotisk
# 8. Reduced hybrid fertility
# 9. F2-breakdown
#
#
# \subsection{Genetic variation}
#
# \subsection{Hardy-Weinberg Equilibrium}
#
# \subsection{Selection}
#
# \subsection{Mutation}
#
# \subsection{Migration}
#
# \subsection{Genetic drift}
#
# \section{Adaptation}
# \subsection{Studying adaption}
# \subsection{Sexual selection}
# \subsection{Kin selection and social behaviour}
# \subsection{Aging and other life history charachters}
#
# \section{The history of life}
# 5. Megaevolution ger nya evolutionära innovationer
#
# 1. Adaptive radiation
# Adaptive radiation: period of evolutionary change in which groups of organisms form many new species whose adaptions allow them to fit different ecological roles in their communities. In evolutionary biology, adaptive radiation is a process in which organisms diversify rapidly into a multitude of new forms, particularly when a change in the environment makes new resources available, creates new challenges, or opens new environmental niches
# Sopeutumislevittäytyminen: vaihe, jossa eliöryhmään syntyy paljon uusia lajeja, joiden adaptaatiot (rakenteet, elintavat) mahdollistavat niiden levittäytymisen
# Anpassningsutbredning:den evolutionärä diverfisieringen av ett taxon I ett antal olika former, anpassade för olika ekologiska nischer och som leder till nya former
#
# Kambrikausi: ilmaston muuttuminen, petojen kehttyminen, muutoksia yksilönkehityksessä
# Exaption
#
# Punctuated equilibrium, Hyppäyksellisen eli pistemäisen tasapainon malli, Punktuerad jämvikt
# Phyletic gradualism
#
# 2. Coevolution, Koevoluuti, Koevolution
# Coevolution: In biology, coevolution occurs when changes in at least two species' genetic compositions reciprocally affect each other’s evolution.
# Koevoluutio: Lajien välinen vastavuoroinen evoluutio, jossa evolutiivinen muutos toisessa lajissa johtaa muutokseen toisessa lajissa
# Saman populaation eri luokkien välillä (esim. sukupuolet, vanhempi, jälkeläinen)
# Koevolution: utvecklingen hos arter i ett ekologiskt samspel. Kan också beteckna utveklingen hos arter som är beroende av varandra, t.ex. parasiter
#
# Diffuusi koevoluutio: holobiontti, symbiottiensa summa
# Koevoluutio: evolutiivisen historiansa aikana esiintyneet yhdessä, tiivis vuorovaikutussuhde
# +/+
# Resurssi-resurssi: juuret ja mykorritsa
# Palvelu-resurssi: pölyttäjä kasvi, muurahaiset-kirvat, puhdistaja-loisitut
# Palvelu-palvelu: acacia
#
# Red queen hypothesis: evolutiivisen kilpavarustelun ja kilpajuoksun eliöiden on jatkuvasti kehityttävä vältääkseen sukupuutto, muut (kehittyvät) eliötkin ovat ympäristöä johon sopeutua
# Optimitilaan
#
# \subsection{Mechanisms of speciation}
# \subsection{Development and evolution}
# NEIRO
#
# Evolutio et systematica
#
# Natura gratia naturae
#
#
# Jakke
#
# 2.2.2016
#
#
#
#
# I Mechanisms of evolution, Evoluution mekamismit, Evolutionens mekanismer
#
# 1. Introduction, Johdanto, Inledning
# Evolution: Descent with modification; the idea that living species are descendants of ancestral species that were different from the present-day ones; also defined more narrowly as the change in the genetic composition of a population from generation to generation. Evolution is change in heritable traits of biological populations over successive generations
# Evoluutio: luonnonilmiö, jonka mukaan organismien muoto ja elämäntapa ovat muuttuneet ja jatkuvasti muuttuvat siten, että jälkeläiset eroavat kantamuodoistaan. Evoluutio on muutosta populaation geenifrekvenseissä
# Evolution: naturfenomen enligt vilken organsimernas form och levnadssätt har förändrats och fortsätter att förändras, så att avkomlingarna skiljer sig från sina förfäder. Evolution är förändrign i populationens allelförhållanden.
# Evolutionen beskriver hur levande organismer förändras över tiden genom ändringar i den genetiska arvsmassan.
# I	II	III	IV	V
# Evolution	Common ancestor
# Yhteinen kantamuoto
# Gemensamt stamform	Gradualism	Species diversification	Natural selection
# Luonnonvalinta
# Naturligt urvak
#
# Variation+Inheritance+selection=evolution
# Muuntelu+Perinnöllisyys+valinta=evoluutio
# Variation+Ärftlighet+selektion=evolution
# Microevolution is the change in allele frequencies that occurs over time within a population.[1] This change is due to four different processes: mutation, selection (natural and artificial), gene flow, and genetic drift. This change happens over a relatively short (in evolutionary terms) amount of time compared to the changes termed 'macroevolution' which is where greater differences in the population occur.
# Mikroevoluutio: lajin sisäinen evoluutio, joka tapahtuu muutoksina populaation geenien esiintymistiheyksissä
# Mikroevolution: Mikroevolution är uppkomsten av småskaliga förändringar i en populations genfrekvens under några generationer. Detta kallas även förändringar under artnivå. Dessa förändringar kan bero på flera saker, exempelvis mutation, genflöde, genetisk drift eller det naturliga urvalet.
#
# Macroevolution is evolution on a scale of separated gene pools.[1] Macroevolutionary studies focus on change that occurs at or above the level of species, in contrast with microevolution,[2] which refers to smaller evolutionary changes (typically described as changes in allele frequencies) within a species or population.[3] Macroevolution and microevolution describe fundamentally identical processes on different time scales.[1][4]
# Makroevoluutio: lajinkehitys; evoluutio, joka johtaa uusien lajien syntyyn. Makroevoluutio voidaan johtaa mikroevoluutiosta isolaation käsitteen mukaanoton avulla.
# Makroevolution innebär större förändringar av genpoolen, till exempel bildandet av nya arter, släkten eller familjer. Biologer definierar makroevolution som förändringar på eller över artnivå [1][2][3][4] Termerna makroevolution och mikroevolution myntades år 1927 av den ryske entomologen Jurij Filiptjenko.
#
# Megaevolution describes the most dramatic events in evolution. It is no longer suggested that the evolutionary processes involved are necessarily special, although in some cases they might be. Whereas macroevolution can apply to relatively modest changes that produced diversification of species and genera and are readily compared to microevolution, "megaevolution" is used for great changes. Megaevolution has been extensively debated because it has been seen as a possible objection to Charles Darwin's theory of gradual evolution by natural selection
# Megaevoluutio: korkeampien systemaattisten taksonien, kuten sukujen, heimojen jne. evoluutio
# Megaevolution: evolutionen av högre systematiska taxoner
#
# 2. History
# The modern evolutionary synthesis is a 20th-century synthesis of ideas from several fields of biology that provides a widely accepted account of evolution. It is also referred to as the new synthesis, the modern synthesis, the evolutionary synthesis,millennium synthesis or the neo-Darwinian synthesis.
# Neodarwinismi: evoluutioteorian 1920-40-luvuilla syntynyt muoto, jossa darwinismin perusperiaate eli luonnonvalinnan teoria on yhdistetty perinnöllisyystieteen teorioihin.
#
# 1. Introduction
# Evolution is not goal orientated
# Why not perfect organisms?
# -existing variation for selection
# -historical restraints
# -compromises
# -stochaism
#
#
#
#
#
# All evolutionary phenomena can be explained in a way consistent with known genetic mechanisms and the observational evidence of naturalists.
# Evolution is gradual: small genetic changes regulated by natural selection accumulate over long periods. Discontinuities amongst species (or other taxa) are explained as originating gradually through geographical separation and extinction. This theory contrasts with the saltation theory of William Bateson (1894).[7]
# Natural selection is by far the main mechanism of change; even slight advantages are important when continued. The object of selection is the phenotype in its surrounding environment.
# The role of genetic drift is equivocal. Though strongly supported initially by Dobzhansky, it was downgraded later as results from ecological genetics were obtained.
# Thinking in terms of populations, rather than individuals, is primary: the genetic diversity existing in natural populations is a key factor in evolution. The strength of natural selection in the wild is greater than previously expected; the effect of ecological factors such as niche occupation and the significance of barriers to gene flow are all important.
# In palaeontology, the ability to explain historical observations by extrapolation from microevolution to macroevolution is proposed. Historical contingency means explanations at different levels may exist. Gradualism does not mean constant rate of change.
#
#
# Evidence for evolution, Evoluution todisteet, Bevis för evolutionen
#
# 1. Fossil, Fossiili, Fossil
# Fossils (from Classical Latin fossilis; literally, "obtained by digging")[1] are the preserved remains or traces of animals, plants, and other organisms from the remote past. The totality of fossils, both discovered and undiscovered, and their placement in fossiliferous (fossil-containing) rock formations and sedimentary layers (strata) is known as the fossil record.
# Fossiili: maa- tai kallioperässä säilynyt entisaikojen (vähintään 10 000 vuotta vanha) eliön jäänne tai jälki, joka voi olla eliö itse, sen osa, valos (cast) tai kivettymä (trace fossil), kun elävän kudoksen molekyylit ovat korvautuneet epäorgaanisilla aineilla.
# Fossil: Fossil (av latin fossus, "uppgrävd") är djur- eller växtdelar som bevarats i typer i sediment eller sedimentära bergarter. En fossilisering kräver att växtdelarna och/eller det omgivande sedimentet mineraliseras. Fossilbildning eller förstening innebär alltså ett utbyte av substans, det vill säga en fysikalisk-kemisk omvandling av material.
# =lämningar av forntida organismer, > 10 000 år, förstening, avtryck, avgjutning, bärnsten
#
# 1. Fossil series, Fossiilisarjat, Fossilserier
# Index fossils, Johtofossiili, Ledfossil
# Index fossils (also known as guide fossils, indicator fossils or zone fossils) are fossils used to define and identify geologic periods (or faunal stages). They work on the premise that, although different sediments may look different depending on the conditions under which they were laid down, they may include the remains of the same species of fossil.
#
# 2. Translational fossil, Välimuotofossiili, intermediärfossil
# A transitional fossil is any fossilized remains of a life form that exhibits traits common to both an ancestral group and its derived descendant group. This is especially important where the descendant group is sharply differentiated by gross anatomy and mode of living from the ancestral group.
# Missing link, Puuttuva rengs, Felande lank
# Archaeopteryx, Tiktaalik, Australopithecus afarensis
#
# 3. Subfossil, Subfossiili, Subfossil
# A subfossil (as opposed to a fossil) is a bone or other part of an organism that has not fully fossilized. This may be because not enough time has elapsed since the animal died, or because the conditions in which the remains were deposited were not optimal for fossilization.
#
# 4. Living fossil, Elävä fossiili, Levande fossil
# A living fossil is a living species (or clade) of organism that appears to be similar to a species otherwise known only from fossils. Normally the similarity is only a superficial physical resemblance between two different species, one extinct, the other extant.
# Elävät fossiilit ovat nykyisin eläviä jäänteitä eliöryhmistä, jotka varhaisempina geologisina aikoina ovat olleet runsaslukuisempia ja laajemmalle levinneitä.
#
# 3. Homologa vs. analoga organ
# Homology: In the context of biology, homology is the existence of shared ancestry between a pair of structures, or genes, in different species.[1] A common example of homologous structures in evolutionary biology are the wings of bats and the arms of primates.
# Analogy: Structural or behavioural similarity in terms of functions between unrelated species or organisms but do not share a common ancestral or developmental origin
#
# Homologia: homologiset rakenteet tai ominaisuudet ova fylogeneettiseltä alkuperältään samansyntyisiä, mutta niiden toiminta tai tehtävä saattaa olla erilainen
# Analogia: analogiset rakenteet; elimiä, joilla on eri evolutiivinen aluperä mutta sama tehtävä
# Homologi: homologi är inom biologi ett evolutionärt begrepp för att beskriva att specifika morfologa eller genetiska egenskaper hos olika organismer har samma ursprung. All systematik och alla fylogenier (hypoteser om släktskap) bygger på att man identifierar homologier hos olika organismer.
# Analogia: Analogi eller homoplasi är inom evolutionsbiologin en beteckning på en morfologisk och/eller genetisk likhet mellan två taxa som inte uppkommit genom nedärvda karaktärer från en gemensam förfader, utan istället genom parallell evolution, konvergent evolution (framkallat av ett likartat levnadssätt) eller reversion (återgång till ett ursprungligare karaktärsstadium).
# 4. Embryology, Embryologia, Embryologi
# Ontogeny recapitulates phylogeny
# Ontogenia rekapituloi fylogenian
# Ontogeni rekapitulerar fylogeni
# 5. Vestigal structures, surkastuma, rudiment
# Vestigiality refers to genetically determined structures or attributes that have apparently lost most or all of their ancestral function in a given species, but have been retained during the process of evolution.[1] Assessment of the vestigiality must generally rely on comparison with homologous features in related species
# Surkastuma: Evolutiivessa kehityksessä tehtävänsä menettänyt elin tai sen osa;esim. ihmisen häntänikamat, umpilisäke.
# Rudiment: Rudiment, ofta kallade rudimentära organ även om långt ifrån alla rudiment är organ, avser inom biologin rester av tidigare utvecklingsformer vars ursprungliga funktion helt eller i huvudsak gått förlorad genom evolution utan att för den skull helt försvunnit (en del rudiment försvinner dock innan djuret fötts eller nått vuxen ålder)
#
# H. sapiens: umpilisäke, korvalihakset, häntänikamat, kulmahampaat, karvapeite
# H. sapiens: blindtarmens bihang, örönmuskeln, svanskota, hörntänder, kroppshår
# 6. Biokemi
# Kromosomer, DNA, proteiner
#
# 7. Behaviour, Käyttäytyminen, Beteende
# 8. Biogeografi
# 9. Pågående evolution
# 1.Industrial melanism, Teollisuusmelanismi, Industrimelanism
# 2. Resitent bacteria, Tesistentit bakteerit, Resistenta bakterier
# 3. Breeding, Jalostus, Förädling
# 10. Taxonomy and Linnean hierarchy, Taksonomia ja linneläinen hierarkia, Taxonomi och Linnés hierarki
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Microevolution, Mikroevoluutio, Mikroevolution
#
# 2. Variation, Muuntelu, Variation
# Genetic variation makes evolution possible
#
# Variation: Genetic variation is a fact that a biological system – individual and population – is different over space. It is the base of the genetic variability of different biological systems in space.
# Muuntelu: periytyvien tai peritymättömien erojen esiintyminen populaation yksilöiden välillä. Fenotyyppinen muuntelu on ympäristön aiheuttaman ja geneettisen munntelun summa
# Variation: det faktum att det förekommer genetiska och icke-ärftliga skillnader mellan individerna i en population
# Epigenetic: epigenetics is the study, in the field of genetics, of cellular and physiological phenotypic trait variations that are caused by external or environmental factors that switch genes on and off and affect how cells read genes instead of being caused by changes in the DNA sequence
# Epigenetiikka: geeniaktiivisuuden säätely ilman geneettisten rakenteiden muutoksia
# Epigenetik: regleringen av genaktiviteten utan strukturella förändringar i det genetiska materialet
#
# Vanhempien kokemat olot vaikuttavat jälkeläisten geenien säätelyyn.
#
# Recombination or genetic recombination: Genetic recombination is the production of offspring with combinations of traits that differ from those found in either parent. In eukaryotes, genetic recombination during meiosis can lead to a novel set of genetic information that can be passed on from the parents to the offspring.
# Rekombinaatio eli geneettinen rekombinaatio: prosessi, jonka vaikutuksesta kaksi eliötä yhdentyy niin, että niiden jälkeläisissä esiintyy geeniyhdistelmiä, joita ei vanhemmilla tavata.
# Rekombination eller genetisk rekombination: den process som leder till att avkomlingarna har annorlunda genkombinationer jämfört med sina föräldrar.
# Epäjatkuva muuntelu: dimorfismi, polymorfismi
# Jatkuva muuntelu eli kvantitattiviset ominaisuudet
# Muuntelun mittaaminen
# Yksilötasolla: Populaation yksilöiden heterotsygotian keskiarvo
# Geenitasolla: heterotsygoottisten lokusten osuus
# Molekyylitasolla: sekvenssin muuntelevien nukleotidien osuus
#
# In ecology and genetics, a reaction norm, also called a norm of reaction, describes the pattern of phenotypic expression of a single genotype across a range of environments.
#
# Genetisk variation sparas
# -diploidy
# -balanserande selection
# heterozygotens fördel, frekvensberoende
#
# Population genetics, Populaatiogenetiikka, Populationsgenetik
#
# The gene pool is the set of all genes, or genetic information, in any population, usually of a particular species.
# Geenipooli: tietyn mendelistisen population geenistön koostumus tiettynä ajankohtana. Geenipoolin, joka pysyy muuttumattomana sukupolvien kuluessa, sanotaan olevan tasapainossa.
# Genpool: En genpool är frekvensen för alla alleler (genvarianter) som finns i en viss population. Genpooler studeras i populationsgenetik och evolutionsforskning. Genpoolen förändras framförallt av att alleler med ökad fitness ökar sin frekvens genom att dess bärare (individer) har större framgång i sin förökning genom naturligt urval och för genvarianterna vidare till nästa generation.
#
# Hardy-Weinberg law: The Hardy–Weinberg principle, also known as the Hardy–Weinberg equilibrium, model, theorem, or law, states that allele and genotype frequencies in a population will remain constant from generation to generation in the absence of other evolutionary influences. These influences include mate choice, mutation, selection, genetic drift, gene flow and meiotic drive.
# Hardy-Weinbergin laki: populaatiogenetiikan peruslaki, jonka mukaan geenifrekvenssit populaatiossa pysyvät muuttumattomina, ellei mikään muu tekijä kuin sattumanvarainen pariutuminen vaikuta.
# Hardy-Weinbergs lag: en populations genfrekvenser kommer att förbli oförändrade om populationen inte påverkas av evolutionära influenser.
#
# 1. no mutations
# 2. random mating
# 3. No selection
# 4. Big population
# 5. No gene flow
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Talförhållandet mellan allelerna konstant vid mendelsk rekombination = Hardy-Weinberg jämvikt
# -> förändrade faktorer -> mikroevolution
#
#
#
# 3. Evolution factors, Evoluutiotekijät, Evolutionsfaktorer
# =regulates variation, changes allele frequencies -> microevolution
# De fem evolutionskrafterna: urval, drift, genflöde, mutation, rekombination
# 1. Natural selection, Luonnonvalinta, Naturligt urval
# Natural selection: Natural selection is the differential survival and reproduction of individuals due to differences in phenotype, it is a key mechanism of evolution.
# Luonnonvalinta: luonnonvalinnan idea on se, että kelpoisimmat muunnokset jäävät olemassaolon taistelussa henkiin ja saavat jälkeläisiä.
# Naturligt urval: Det naturliga urvalet är en nödvändig delprocess i evolutionen. Charles Darwin var den som tillsammans med Alfred Russell Wallace, lade fram teorin om det naturliga urvalet som förklaring till de observerade skillnaderna mellan olika arter.
#
# Konkurrens -> de mest dugliga överlever -> överför sina egenskaper och gener -> påverkar genernas talförhållanden i populationen i nästa generation, genetiska representation -> mikroevolution
#
# Selection unit=individ
# Morfologi, Fysiologi, Etologi
# 1. Överflöd av individer
# 2. Stabila populationer
# 3. Miljöns bärförmåga överskrids
# -> kamp om tillvaron
# 4. Variation
# -> olika fitnesskillnader
# 5. Ärftlighet
# -> evolution
#
#
#
# 2. Fitness and adaption
# Fitness: Fitness (often denoted w in population genetics models) is a central idea in evolutionary and sexual selection theories. It can be defined either with respect to a genotype or to a phenotype in a given environment. In either case, it describes individual reproductive success and is equal to the average contribution to the gene pool of the next generation that is made by an average individual of the specified genotype or phenotype.
# Kelpoisuus: perinnöllisyystieteessä yksilön tai genotyypin suhteellinen kyky saada lissätymiskykyisiä jälkeläisiä
# Fitness: relativ fortplantningsförmåga
# Fitness,Kelpoisuus, Duglighet
# 1. Survival, Elossasäilyminen, Överlevnad
# 2. Reproduktion, Lisääntyminen, Reproduktion
# 3. Omsorg
#
# In biology, an adaptation, also called an adaptive trait, is a trait with a current functional role in the life of an organism that is maintained and evolved by means of natural selection. Adaptation refers to both the current state of being adapted and to the dynamic evolutionary process that leads to the adaptation. Adaptations enhance the fitness and survival of individuals.
# Sopeutuma: eliön rakenteessa tai toiminnassa mikä tahansa muutos, joka antaa sille paremman mahdollisuuden tulla toimeen ympäristössään. Adaptaation tuloksena eliö sopeutuu rakenteellisesti ja toiminnallisesti ympäristöönsä.
# Adaption: genetiskt betingad förändring som leder till att en organism med tiden blir batter anpassad till sin miljö. Adaption avser någon strukturell eller funktionell förändrng som ökar en organisms möjligheter att överleva och reproducera sig.
# Inclusive fitness
# Morphology, Physiology, Etology
#
# Selektionsformer
# 1.Stabilizing,
# Tasapainottava,
# Stabiliserande
# 	2. Directional
# Suuntaava
# Riktad	3. Disruptive
# Hajottava
# Diverfisierande
#
#
#
#
#
#
#
#
#
#
# 2. Sexual selection, Sukupuolivalinta, Sexuell selection
# Sexual selection: Sexual selection is a mode of natural selection where typically members of one gender choose mates of the other gender to mate with, called intersexual selection, and where females normally do the choosing, and competition between members of the same gender to sexually reproduce with members of the opposite sex, called intrasexual selection.
# Sukupuolivalinta: on valinnan muoto, jossa sukupuoleen liittyvillä ominaisuuksilla on tärkeä merkitys.
# Sexuell selektion: teori som säger att hanar av vissa arter konkurrerar om honorna och att vissa karakteristika då utvecklas i denna konkurrens, antingen prydnader eller beteenden som lockar honorna, eller vapen som utnyttjas i kampen med andra hanar.
#
# =more likely to obtain mates -> sexual dimorphism
# Intersexual vs. intrasexual
# Fischer 1930 runaway process
# Zahov 1975 handicap principle
#
# Ornament, Ornamentti, Ornament
# 3. Genetic drift, Geneettinen ajautuminen tai satunnaisajautuminen, genetisk drift
# Genetic drift: Genetic drift (or allelic drift) is the change in the frequency of a gene variant (allele) in a population due to random sampling of organisms.
# Geneettinen ajautuminen: pienissä populaatioissa oleva tekijä, jonka vaikutuksesta geenifrekvenssit populaatiossa heilahtelevat sattumalta edestakaisin, kunnes niiden arvoksi lopulta tulee ykkönen tai nolla.
# Genetisk drift: Genetisk drift är en av delmekanismerna i evolutionen. Den är en stokastisk effekt och uppkommer på grund av den slumpmässighet som råder i vilka individer i populationerna som lyckas (bäst) med att överleva och reproducera sig.
# 1. Founder effect, perustajanvaikutus, grundareffekten
# Founder effect: In population genetics, the founder effect is the loss of genetic variation that occurs when a new population is established by a very small number of individuals from a larger population. It was first fully outlined by Ernst Mayr in 1942,[1] using existing theoretical work by those such as Sewall Wright.
# Perustajanvaikutus: populaatiogeneettinen ilmiö, jossa uuden, muuttoliikkeen kautta syntyneen population geenitaajuudet eli geenifrekvenssit voivat sattumalta poiketa peruspopulaation geenitaajuuksista:
# Grundareffekten: Grundareffekten är den förlust av genetisk variation som uppkommer när en ny mindre population grundas av ett mindre antal individer från en större population. Grundareffekten är ett extremfall av genetisk drift.[1][2] Begreppet är centralt inom populationsgenetiken och beskrevs fullständigt för första gången av Ernst Mayr år 1952[3], baserat på teoretiskt arbete av bland annat Sewall Wright.
#
# 2. Bottleneck effect, pullonkaulailmiö, flaskhalseffekten
# A population bottleneck (or genetic bottleneck) is a sharp reduction in the size of a population due to environmental events (such as earthquakes, floods, fires, disease, or droughts) or human activities (such as genocide). Such events can reduce the variation in the gene pool of a population; thereafter, a smaller population with a correspondingly smaller genetic diversity, remains to pass on genes to future generations of offspring through sexual reproduction.
# 4. Gene flow (migration), geenivirta (migraatio), genflöde (migration)
# Gene flow: In population genetics, gene flow (also known as gene migration) is the transfer of alleles or genes from one population to another.
# Geenivirta: Geenien siirtyminen populaatiosta toiseen lissäntymisvälikappaleiden, kuten siementen, siitepölyn ja itiöiden, leviämisen tai yksilöiden siirtymisen, migration, kautta. Geenivirta voi johtaa geenifrekvenssien muutoksiin ja on siten evoluutiossa vaikuttava tekijä.
# Genflödet: Genflöde är när gener överförs från en population till en annan population av samma art. Då flera populationer utbyter gener mellan varandra i en kedja kan det uppstå en rascirkel. Genflöde är den enda evolutionsprocessen som gör populationerna genetiskt mer lika varandra. Genflöde gör också att genpoolerna blir större.
#
#
#
# 4. Speciation, Lajiutuminen, Artbildning
# Speciation is the evolutionary process by which new reproductively isolated biological kinds, species, arise. The biologist Orator F. Cook was the first to coin the term 'speciation' for the splitting of lineages or "cladogenesis," as opposed to "anagenesis" or "phyletic evolution" occurring within lineages.
# Lajiutuminen: lajien evolutiivinen muotoutuminen lisääntymisisolaation kehittyessä populaatioiden tai populaatioryhmien välille
# Artbildning är när nya arter uppstår, och orsaken till livets stora mångfald. Forskare tror att det finns cirka 10 miljoner arter på jorden just nu, men endast 1,4 miljoner av dessa har blivit upptäckta, vetenskapligt beskrivna och därmed namngivna. Nya arter bildas alltid från en redan befintlig art.
#
# Populationen isoleras I delpopulationer, olika evolutionsfaktorer -> anagenes I olika riktiningar -> kladogenes -> macroevolution
# Anagenesis, also known as "phyletic transformation", is when the new morphospecies is a result of rapid evolution in the ancestral form without speciation taking place, such that there are no remaining other populations of the ancestor species and the species can be considered extinct. The ancestor species is therefore superseded by the new species it morphs into. Anagenesis is in contrast to the branching speciation known as cladogenesis.
# Anageneesi: progressiivisen evolution muoto, johon liittyy uusien eliten, rakennetyyppien ja rakenneratkaisujen syntymistä. Anageneesi johtaa uuden lajin syntyyn kantalajin haarautumatta kahdeksi tai useammaksi lajiksi. Julian Huxleyn mukaan anagenees on yleistermi kaikenlaiselle evoluutiolle, joka johtaa biologisen sopeutumisen paranemiseen.
# Cladogenesis is an evolutionary splitting event where a parent species splits into two distinct species, forming a clade.[1]This event usually occurs[citation needed] when a few organisms end up in new, often distant areas or when environmental changes cause several extinctions, opening up ecological niches for the survivors.
# Kladogeneesi: fyleettisen evolution muoto, jossa yksi laji haarautuu kahdeksi lajiksi.
#
# Divergent evolution is the accumulation of differences between groups which can lead to the formation of new species, usually a result of diffusion of the same species to different and isolated environments which blocks the gene flow among the distinct populations allowing differentiated fixation of characteristics through genetic drift and natural selection.
#
# Convergent evolution is the independent evolution of similar features in species of different lineages. Convergent evolution creates analogous structures that have similar form or function, but that were not present in the last common ancestor of those groups.[1] The cladistic term for the same phenomenon is homoplasy, from Greek for same form.
#
# Parallel evolution is the development of a similar trait in related, but distinct, species descending from the same ancestor, but from different clades.
#
#
# Sympatric speciation is the process through which new species evolve from a single ancestral species while inhabiting the same geographic region. In evolutionary biology and biogeography, sympatric and sympatry are terms referring to organisms whose ranges overlap or are even identical, so that they occur together at least in some places.
# Sympatrinen lajiutumien syntyy ilman maantieteellistä eristymistä, ts. lisääntymisisolaation syntyminen deemin sisällä
#
# Allopatric speciation (from the ancient Greek allos, "other" + Greek patris, "fatherland") or geographic speciation is speciation that occurs when biological populations of the same species become vicariant, or isolated from each other to an extent that prevents or interferes with genetic interchange.
# Allopatrinen lajiutuminen on seurausta maantieteellisestä eristyneisyydestä, ts. populaatioiden välille kertyy niiden eläessä maantieteellisesti eristyneinä niin paljon geneettisiä eroja erilaisten valintapaineiden vuoksi.
# Allopatric, Allopatrinen, Allopatrisk	Sympatric, Sympatrinen, Sympatrisk
# 1. Dikopatric	1. Hybridisation
# 2. Peripatric	2. Polyploidy
# 3. Rengaslajit, RIngarter	3. Habitat difference
# 	4. Sexual selection
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Reproductive barriers or isolation mechan isms
# Lisääntymisesteet eli isolaatiomekanismit
# Förökningsbarriärer alltså isolationsmekanismer
# 1. Geographical, Maantieteellinen, Geografisk	Prezygotic
# Pretsygoottinen
# Prezygotisk
# 2. Habitat, Habitaatti, Habitat
# 3. Temporal, Temporaalinen, Tidsmässig
# 4. Behavioral, Käyttäytyminen, Beteende
# -
# 5. Mechanical, Mekaaninen, Mekanisk
# 6. Gametic, Gameettinen, Gametisk
# -
# 7. Reduced hybrid viability	Postzygotic
# Postzygoottinen
# Postzygotisk
# 8. Reduced hybrid fertility
# 9. F2-breakdown
#
#
#
# 5. Megaevolution ger nya evolutionära innovationer
#
# 1. Adaptive radiation
# Adaptive radiation: period of evolutionary change in which groups of organisms form many new species whose adaptions allow them to fit different ecological roles in their communities. In evolutionary biology, adaptive radiation is a process in which organisms diversify rapidly into a multitude of new forms, particularly when a change in the environment makes new resources available, creates new challenges, or opens new environmental niches
# Sopeutumislevittäytyminen: vaihe, jossa eliöryhmään syntyy paljon uusia lajeja, joiden adaptaatiot (rakenteet, elintavat) mahdollistavat niiden levittäytymisen
# Anpassningsutbredning:den evolutionärä diverfisieringen av ett taxon I ett antal olika former, anpassade för olika ekologiska nischer och som leder till nya former
#
# Kambrikausi: ilmaston muuttuminen, petojen kehttyminen, muutoksia yksilönkehityksessä
# Exaption
#
# Punctuated equilibrium, Hyppäyksellisen eli pistemäisen tasapainon malli, Punktuerad jämvikt
# Phyletic gradualism
#
# 2. Coevolution, Koevoluuti, Koevolution
# Coevolution: In biology, coevolution occurs when changes in at least two species' genetic compositions reciprocally affect each other’s evolution.
# Koevoluutio: Lajien välinen vastavuoroinen evoluutio, jossa evolutiivinen muutos toisessa lajissa johtaa muutokseen toisessa lajissa
# Saman populaation eri luokkien välillä (esim. sukupuolet, vanhempi, jälkeläinen)
# Koevolution: utvecklingen hos arter i ett ekologiskt samspel. Kan också beteckna utveklingen hos arter som är beroende av varandra, t.ex. parasiter
#
# Diffuusi koevoluutio: holobiontti, symbiottiensa summa
# Koevoluutio: evolutiivisen historiansa aikana esiintyneet yhdessä, tiivis vuorovaikutussuhde
# +/+
# Resurssi-resurssi: juuret ja mykorritsa
# Palvelu-resurssi: pölyttäjä kasvi, muurahaiset-kirvat, puhdistaja-loisitut
# Palvelu-palvelu: acacia
#
# Red queen hypothesis: evolutiivisen kilpavarustelun ja kilpajuoksun eliöiden on jatkuvasti kehityttävä vältääkseen sukupuutto, muut (kehittyvät) eliötkin ovat ympäristöä johon sopeutua
# Optimitilaan
#
#
# Evolutionary developmental biology, Evolutiivinen kehitysbiologia, Evolutionär utvecklingsbiologi
#
#
#
# Evolutiivinen kehitysbiologia: tutkii yksilönkehityksen evoluutiota, miten/miksi erot eri eliöiden yksilönkehityksessä syntyvät, ja mitä tämä voi kertoa eliöiden evoluutiosta
# Yksilönkehitys: saman geneettisen perimän omaavien solulinjojen ohjelmoitu kasvu- ja errilastumistapahtuma
# Morfogeneesi on seurausta solujen kromosomiston, soluliman, sisäisen soluympäristön ja eliön ulkoisen ympäristön (monimutkaisesta) vuorovaikutuksesta
#
# Fylotyyppinen muoto
# Hourglass model
#
# 2. Mekanismit
# 1. Säätelygeenin kohde ja ilmentyminen muuttuu
# Housekeeping geenit: perismetabolia
# Terminal target geenit: soluspesifiset geenit
# Regulatroy geenit
#
# Homeotic genes are genes which regulate the development of anatomical structures in various organisms such as insects, mammals, and plants. This regulation is done via the programming of various transcription factors by the homeotic genes, and these factors affect genes through regulatory genetic pathways.[1] Mutations in the homeotic genes can occur, leading to what are known as homeotic mutants. These mutants display ectopic placement of body parts (such as antennae growing at the posterior of the fly instead of at the head) or abnormal expression of the homeotic gene. Mutations that lead to these ectopic placements are usually lethal to the organism.
# Hox genes (also known as homeotic genes) are a group of related genes that control the body plan of an embryo along the cranio-caudal (head-tail) axis. After the embryonic segments have formed, the Hox proteins determine the type of segment structures (e.g. legs, antennae, and wings in fruit flies or the different types of vertebrae in humans) that will form on a given segment. Hox proteins thus confer segmental identity, but do not form the actual segments themselves.[1]Hox genes are defined as having the following properties: Their protein product is a transcription factor. They contain a DNA sequence known as the homeobox. In many animals, the organization of the Hox genes in the chromosome is the same as the order of their expression along the anterior-posterior axis of the developing animal, and are thus said to display colinearity
# Homeobox is a DNA sequence, around 180 base pairs long, found within genes that are involved in the regulation of patterns of anatomical development (morphogenesis) in animals, fungi and plants. These genes encode homeodomain protein products that are transcription factors sharing a characteristic protein fold structure that binds DNA.
#
# 2. Heterokronia: suhteellinen aika muuttuu
# Allometry is the study of the relationship of body size to shape,[1] anatomy, physiology and finally behaviour,[2] first outlined by Otto Snell in 1892,[3] D'Arcy Thompson in 1917 in On Growth and Form[4] and Julian Huxley in 1932.[5] Allometry is a well-known study, particularly in statistical shape analysis for its theoretical developments, as well as in biology for practical applications to the differential growth rates of the parts of a living organism's body.
# Neoteny (/niːˈɒtᵻni/ /niːˈɒtni/[1][2][3] or /niːˈɒtəni/[4]), also called juvenilization,[5] is one of the two ways by which paedomorphism can arise. Paedomorphism or paedomorphosis is the retention by adults of traits previously seen only in the young, and is a subject studied in the field of developmental biology. Neoteny is found in modern humans.[6] Paedomorphism can also be the retention of larval traits which is commonly studied in salamanders.[7] In neoteny, the physiological (or somatic) development of an organism (typically an animal) is slowed or delayed. In contrast, in progenesis, sexual development occurs faster. Both processes result in paedomorphism, a type of heterochrony.
# 3. Heterotopia: paikka muuttuu
# 4. Heterometria: suhteellinen määrä muuttuu
# 5. Heterotypia: uudelleen järjestely
# 6. Geenin mutaatio
#
#
# \section{Systematics}
# 1. Introduction, Johdanto, Inledning
# Biosystematics: is the study of the diversification of living forms, both past and present, and the
# relationships among living things through time.
# Systematiikka: eliöiden järjestelyä; Tutkii eliöiden monimuotoisuutta ja niiden välisiä [evolutiivisia] suhteita, erityisesti siltä osin kuin niillä on merkitystä eliöryhmien (taksonien) fylogeneettisten suhteiden kannalta. Systematiikka on tapahtuneeseen evoluutioon perustuvaa luokittelututkimusta
# Systematik: vetenskapen om organismernas mångfad och deras evolutionära släktskapsförhållanden
# SYSTEMATIIKKA SELITTÄÄ BIOLOGISTA MONIMUOTOISUUTTA PÄÄTTELEMÄLLÄ SUKULAISUUSUHTEET JA ELIÖITÄ YHDISTÄVÄT AINUTLAATUISET MUUTOKSET
# Phylogeny: evolutionary history, development and relationships among groups of organisms
# Fylogenia: eliöyksilön tai eliöryhmän evolutiivinen historia
# Fylogeni: organismernas evolutionära historia
# Vain yksi oikea fylogenia, synapomorfian perusolettamus, optimaalisuuskriteeri
#
#
#
#
# 2. Taxonomy, Taksonomia, Taxonomi
# Taxonomy: description, identification, nomenclature and classification of organisms. Taxonomy (from Ancient Greek: τάξις taxis, "arrangement", and -νομία -nomia, "method"[1]) is the science of defining groups of biological organisms on the basis of shared characteristics and giving names to those groups. Organisms are grouped together into taxa (singular: taxon) and given a taxonomic rank; groups of a given rank can be aggregated to form a super group of higher rank and thus create a taxonomic hierarchy.
# Taksonomia: eliöiden tieteellinen luokittelu; biologian ala, joka sisältää sekä nykyisten että sukupuuttoon kuolleiden eliöiden kuvauksen, nimeämisen ja luokittelun (ryhmittelyn). Eliöiden kuvaaminen, tunnistaminen, nimeäminen sekä alustava luokittelu
# Taxonomi: beskrivandet, identifikationen, nomenklaturen och klassifikationen av organismer
#
# 1,Description, Kuvaus, Beskrivning
# Priority rule, prioriteettisääntö, prioritetsregeln
# Tyyppinäyte: näyte, jonka perusteella jokin laji on ensimmäisen kerran kuvattu; säilytetään biologisissa museoissa
# 2, Nomenclature, Nimeäminen, Nomenklatur
# Ursus arctos Linnaeus 1758
# Binominal nomenclature, Binominaalinen nimistö, Binominal nomenklatur
# Sukunimi, Släktnamn
# Lajinimi, Artepitet
#
# Fumaria officinalis L., Sp. Pl. vol II, p. 700 (1753);. Typus: LINN 881.13
#
# 3. Methods for phylogenetic analysis, Fylogeneettisen analyysin metodologiat, Metoder för fylogenetisk analys
#
# 1. Phenetics, Fenetiikka, Fenetik
# In biology, phenetics /fᵻˈnɛtɪks/, also known as taximetrics, is an attempt to classify organisms based on overall similarity, usually in morphology or other observable traits, regardless of their phylogeny or evolutionary relation. It is closely related to numerical taxonomy which is concerned with the use of numerical methods for taxonomic classification.
# Feneettinen taksonomia: tieteenhaara, joka ryhmittelee eliöitä niiden eri fenotyyppisten ominaisuuksien keskinäisten samankaltaisuuksien tai eroavuuksien perusteella ottamatta huomioon analogiaa, homologiaa tai fylogeniaa.
#
# 2. Evolutionary systematics, Evolutiivinen systematiikka, Evolutionär systematik
# Evolutionary taxonomy, evolutionary systematics or Darwinian classification is a branch of biological classification that seeks to classify organisms using a combination of phylogenetic relationship (shared descent), progenitor-descendant relationship (serial descent), and degree of evolutionary change. This type of taxonomy may consider whole taxa rather than single species, so that groups of species can be inferred as giving rise to new groups.[1] The concept found its most well-known form in the modern evolutionary synthesis of the early 1940s.
# Evolutuuvinen systematiikka: Taksonomian perinteinen tutkimushaara, luokittelee eliöt feneettisen ja fylogeneettisen ominaaisuuksien perusteella
#
# 3. Cladistics, Kladistiikka, Kladistik
# Cladistics: is an approach to biological classification in which organisms are categorized based on shared derived characteristics that can be traced to a group's most recent common ancestor and are not present in more distant ancestors.
# Kladistiikka: taksonomian tutkimussuunta, jossa taksonit ryhmitellään yhteisestä kantamuodosta erkanemisen ajankohdan mukaan monofyleettisiin ryhmiin (kladeihin).
# Kladistik: Kladistiken skiljer sig från äldre taxonomiska metoder genom att den fokuserar på evolutionära samband snarare än alla likheter hos organismer, och genom att den bygger på utnyttjande av kvantitativ analys.
#
# Clade: monophyletic grouping that includes an ancestral species and all its lineal descendants
# Kladi: monofyleettinen eliryhmä, joka sisältääyhteisen kantamuodon ja sen kaikki  lineaariset jälkeläiset
# Klad: monofyletisk gruppering av organismer, vilken innehåller den gemensamma förfadern och dess alla lineära ättlingar
#
# Monophyletic: Clade, the group consists of an ancestral species and all its descendants
# Monofyleettinen: tukena vähintään yksi apomorfia
# Monofyketisk: stöds av åtminstone en apomorfi
# Paraphyletic: group consisting of all the descendants of the group’s last common ancestor minus a small number of monophyletic subgroups of descendants
# Parafyleettinen: taksoni, joka käsittää jäsenten yhteisen lähimmän kantamuodon mutta ei kaikkia sen jälkeläisistä
# Parafyletisk: Parafyli (grekiska: pará, vid sidan av + phylos, stam) är ett taxonomiskt klassifikationsbegrepp som används inom biologin och har sitt ursprung i kladistiken. En grupp organismer ingår i en parafyletisk grupp när alla representanter härstammar från samma anfader men inte alla av denne anfaders avkommor är inkluderade.
#
# Polyphyletic: A polyphyletic (Greek for "of many races") group is characterized by one or more homoplasies: phenotypes which have converged or reverted so as to appear to be the same but which have not been inherited from common ancestors. Alternatively, polyphyletic is used to describe multiple ancestral sources regardless of convergence.
# Polyfyleettinen: yksi plesiomorfia, ei apomorfioita
# Polyfyletisk: Polyfyli (grekiska: polýs, många + phylos, stam) är ett taxonomiskt klassifikationsbegrepp som används inom biologin och har sitt ursprung i kladistiken. En grupp organismer ingår i en polyfyletisk grupp när olika representanter för gruppen inte är varandras närmaste släktingar. De har inte en nära gemensam anfader, utan deras gemensamma anfader är också anfader till andra organismer.
#
# apomorhy: shared derived trait
# apomorfia: eliöitä yhdistäviä evolutiivisia uutuuksia
# apomorfi: evolutionär nyhet som förenenar en organismgrupp
# Synapomorfia, autapomorfia
#
# Plesiomorhy: a character state that a taxon has retained from its ancestors
# Plesiomorfia: fylogeniassa ominaisuuden alkuperäinen perusominaisuus, taksoni on säilyttänyt esi-isiensä ominaisuuden samanlaisena
# Plesiomorfi: en egenskap som ett taxon har erhållit från sina förfäder
#
# Homoplasy: convergence, shared by two or more organisms but is absent from their common ancestor or from a later ancestor in the lineage leading to one of the organisms
# Homoplasia: samankaltaisuus, joka on seurausta konvergentisesta, parallellisesta tai reversaalista evoluutiosta eikä ole sellaisenaan peritty
# Homoplasi: egenskap som två eller flera organismer delar sinsemellan men som är frånvarande från deras gemensamma förfader eller en senare förfader i utvecklingslinjen som leder till en av organismerna
#
# Ingroup, Sisäryhmä, Ingrupp: kladistisen analyysin kohteena oleva kladi
# Outgroup, Ulkoryhmä. Utgrupp: kladistisessa analyysissä sisäryhmän vertailukohteena oleva kladi
#
#
# 4. Classification, Luokittelu, Klassifikation eller klassificering
# Taxon: a group of one or more populations of organisms seen by taxonomists to form a unit. A taxon includes all included taxa of lower rank and individual organisms
# Taksoni: mikä tahansa eliöiden sukulaisuussuhteiden perusteella nimetty eliöryhmä, joka on virallisesti kuvattu ja jolle on annettu tieteellinen nimi
# Taxon, eller i plural taxa, är det allmänna begreppet för enheterna/avdelningarna inom biologisk systematik. Dock varierar storleken och innehållet för ett taxon med vilken systematisk nivå man talar om. Ett taxon kan exempelvis utgöras av en underart, en art, ett släkte, en grupp av närbesläktade arter, en familj, en ordning, en grupp närbesläktade familjer, eller ännu större systematiska enheter.
# Taxonomic rank, Taksonitaso, taxonomisk rang: the relative level of a group of organisms (a taxon) in a taxonomic hierarchy
# Domain	Domeeni	Domän
# Kingdom	Kunta	Rike
# Phylum, division	Pääjakso, pääkaari	Fylum, division
# Class	Luokka	Klass
# Order	Lahko	Ordning
# Family	Heimo	Familj
# Genus	Suku	Släkte
# Species	Laji	Art
#
# Underart: ”Underarten, eller den geografiska rasen, är en geografiskt lokal underavdelning av arten, som skiljer sig genetiskt och taxonomiskt från andra underavdelningar av arten”.
# Varietet är en rang inom systematisk botanik som tillämpas för lo­kala populationer av en art eller underart. Förkortas "var.", efter latinets varietas. Rangen är lägre än art och underart, men högre än form.
# Inom botaniken avser begreppet form (eller forma) en rang under art. Hierarkiskt står den också under underart och varietet. Form användes mest förr om särpräglade avvikelser inom en art. Oftast särskiljs formen genom en enda unik karaktär
# 5. Methods, Metodot, Metoder
# 1. Traditioneltt: homologi I morfologi, fysiologi eller etologi
# 2. Modernt: kromosomer, DNA, protein, molecular clock
# Parittainen linjaus
# Multiple sequence alignments
# Orthologous genes= homologous genes found in different species as a result of speciation
# Paralogous genes= homologous genes within a species that result from gene duplication
#
# \subsection{Estimating evolutionary trees}
# \subsection{Phylogenomics}
#
# \section{History of life}
# History of Life, Elämän historia, Livets historia
# 4 600 mya	Maapallo syntyy, Jorden föds
# 3 800 mya	1. Elinympäristö maan muodostuessa
# tulivuoria, salamoita, UV-säteily, radioaktiivisuus
# H2,N2,CO2,CH4,NH3
#
# 2. Missä elämä syntyi?
# 1. Matalat merenlahden stromatoliitit
# 2. Syvillä merenpohjilla
# Hydrothermal vent,
# 3. Avaruus, panspermia
#
# 3. Kemiallinen evoluutio
# 1. Monomeerit, Monomerer
# esim. aminohapot, nukleiinihapot
# Stanley Miller 1953
#
# 2. Polymeerit, Polymerer
# 3. Replikaatio ja perinnöllisyys, Replikation och ärftlighet
# 4. Yhteistoiminta, Samarbete
# 5. Kalvo, protobiontit
# Abiogenesis, Abiogeneesi, Abiogenes
# Protocell: A protocell (or protobiont) is a self-organized, endogenously ordered, spherical collection of lipids proposed as a stepping-stone to the origin of life.[1][2] A central question in evolution is how simple protocells first arose and how they could differ in reproductive output, thus enabling the accumulation of novel biological emergences over time, i.e. biological evolution.
# Protobiontti, Protobiont
# 3 000 mya	4. Syanobakteerit, Cyanobakterier
# 1. H2S = vetysulfidi, rikkivety
# Fotosynteesi -> happea
# 2. Happi hapettaa raudan -> rautaoksideja
# otsoni-> vähemmän UV-valoa
# 3. Anaerobiset bakteerit kuolevat
# 4. Jääkausi
#
# 1 500 mya	5. Endosymbioosi Lynn Margulis 1966
# Symbiogenesis, or endosymbiotic theory, is an evolutionary theory that explains the origin of eukaryotic cells from prokaryotes. It states that several key organelles of eukaryotes originated as a symbiosis between separate single-celled organisms. According to this theory, mitochondria, plastids (for example chloroplasts), and possibly other organelles representing formerly free-living bacteria (prokaryotes) were taken inside another cell as an endosymbiont around 1.5 billion years ago. Molecular and biochemical evidence suggest that mitochondria developed from proteobacteria (in particular, Rickettsiales, the SAR11 clade,[1][2] or close relatives) and chloroplasts from cyanobacteria (in particular, nitrogen-fixing filamentous cyanobacteria[
# Endosymbioosi: symbioottinen vuorovaikutussuhde kahden lajin välillä, joista toinen elää toisen sisällä aiheuttamatta sille haittaa; esim eräät alkueläimissä elävät bakteerit ja eläinten ruoansulatuskanavassa elävät mikro-organismit.
# Endosymbioositeoria: teoria, jonka mukaan aitotumaisten solujen viherhiukkaset ovat alun perin endosymbioottisia syanobakteereita tai niistä kehittyneitä Prochlorophyta-ryhmän leviä, ja solujen mitokondriot ovat alun perin bakteereita.
# Endosymbiontteorin är den idag dominerande teorin om hur uppkomsten av eukaryota celler har gått till. Teorin går ut på att mitokondrier och plastider (t ex kloroplaster) en gång i tiden var frilevande prokaryoter (bakterier) som upptogs av andra prokaryoter och utvecklat ett liv i symbios. Det endosymbiontiska samarbetet mellan prokaryoterna har lett till utvecklingen av dagens eukaryota organismer.
#
#
#
#
# 700 mya	6. Multicellular organisms, Monisoluisia eliöitä, Flercelliga organismer
# Multicellular organisms are organisms that consist of more than one cell, in contrast to unicellular organisms.[1] All species of animals, land plants and filamentous fungi are multicellular, as are many algae while a few organisms are partially uni- and partially multicellular, like slime molds and social amoebae such as the genus Dictyostelium.
# En flercellig organism är en organism som till skillnad från encelliga organismer består av flera specialiserade celler.
#
# 1. elinikä pitenee, suurempia yksilöitä, längre livslängd, större individer
# 2. sisäinen tasapaino, inre homeostas
# 3. riskin levittäminen, erilaistuminen, riskfördelning, differentiering
# The colonial theory, Koloniateoria, Koloniteorin
# The syncytial theory, Synsytiateoria, Syncytiumteorin
#
# Yksinkertainen monisoluisuus
# 1. Tarttumismolekyylit sitovat mittoottisesti syntyneet tytärsolut yhteen
# 2. Sukusolut ja somaatiset solut joskus erikseen
# 3. Kaikki solut yhteydessä ympäristöön 4. Solujenvälinen viestintä ja ravinteidensiirto vähäistä	Monimutkainen monisoluisuus
# 1. Useita erilaisia solutyyppejä
# 2. Ravinteiden ja viestien kuljetusmekanismi
# 3. Vain osa soluista suorassa yhteydessä ympäristöön
# 4. Solujenvälinen viestintä runsasta  Yksilönkehitys
#
# En stor cell kan inte stöda protoplasman
# Diffusionsavståndet blir för stort i stora celler – ökning av ytan går i kvadrat, medan ökning av volymen går i kubik
# En stor cell avdunstar för mycket vatten
# Möjlighet för specialisering
# Stora djur svårare att äta än små
#
# 7. Suvullinen lisääntyminen, Sexuell reproduktion
# Ediacarakausi
# Hydrostaattinen tukiranka
